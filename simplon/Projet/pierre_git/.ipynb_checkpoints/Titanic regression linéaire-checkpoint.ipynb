# %% [markdown]
# ### Titanic régression linéaire

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score
import pandas as pd
import seaborn as sns

# %% [markdown]
# ### Importation des data set

# %%
train = r"C:\Users\Shadow\Desktop\brief_projet_2\train.csv"

df_train = pd.read_csv(train, sep=',')
df_train.head()

# %%
df_train_y = def_train.target
df-train['Survided'] = df_train_y

# %% [markdown]
# ### Suppression des valeurs manquantes

# %%
num_missing_X = lambda x: sum(x.isnull())
print("Valeurs manquantes par colonne:\n", df_train.apply(num_missing_X, axis=0))

# %%
# Out:
# Valeurs manquantes par colonne:
#  PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %% [markdown]
# ### Matrice de corélation.

# %%
matrice_corr = df_train.corr().round(1)
sns.heatmap(data=matrice_corr,annot=True)

# %% [markdown]
# ### Creation d'un objet de creation linéaire

# %%
regr = linear_model.LinearRegression()

# %% [markdown]
# ### Entrainement du modef utilsant l'ensemble entrainement
